# %% [markdown]
# # <font color = 'brown'>Politics Project (공정배 민유진 유영재 장은경)<font>

# %% [markdown]
# ## <font color = 'blue'>주제 : 네이버 상위권 뉴스와 정부 지지율 관계성 파악<font>
# > - 정치 / 경제 / 사회 3가지 카테고리를 이용
# - 기사의 헤드라인의 키워드 빈도수를 이용
# - 기사 랭크 top5 와 top30 나눠서 분석
# - 문재인 정부의 1년 간의 지지율 데이터 추출 및 관계도 파악 (2017년 11월 1일 ~ 2018년 11월 15일)

# %% [markdown]
# ## <font color = 'red'>기사 크롤링 함수<font>

# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen

import numpy as np
import pandas as pd


# 크롤링 하는 함수
def crawling_news(startDay, endDay, numOfNews):
    Day = []
    polTitle = []
    ecoTitle = []
    socTitle = []
    totalTitle = []
    
    # 시작과 끝 날짜 입력
    startDay, endDay = str(startDay), str(endDay)
    
    # 날짜목록 만들기
    dayList = pd.date_range(start = startDay, end = endDay)
    dayList = dayList.strftime('%Y%m%d').tolist()
    
    # 카테고리
    categorys = ['100', '101', '102']  # 100 : 정치 / 101 : 경제 / 102 : 사회
    
    # 크롤링
    url = 'https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId={}&date='
    
    for category in categorys:
        urlBasic = url.format(category)
    
        for day in dayList:
            # html 수집
            urlDay = urlBasic + day
            html = urlopen(urlDay)
            soup = BeautifulSoup(html, "lxml")
        
            # 기사 헤드라인 수집
            newsTitle = soup.find_all('div', 'ranking_headline')
        
            for n in range(numOfNews):
                # 정치 기사만 수집
                if category == '100':
                    Day.append(day)
                    polTitle.append(newsTitle[n].get_text().strip())
                
                # 경제 기사만 수집
                if category == '101':
                    ecoTitle.append(newsTitle[n].get_text().strip())
                
                # 사회 기사만 수집
                if category == '102':
                    socTitle.append(newsTitle[n].get_text().strip())
    
    # 정치/경제/사회 헤드라인 합치기 과정
    for n in range(len(polTitle)):
        tmpTitle =  polTitle[n] + ' ' + ecoTitle[n] + ' ' + socTitle[n]
        totalTitle.append(tmpTitle)
    
    # 데이터 프레임 생성
    data = {'날짜' : Day, '정치' : polTitle, '경제' : ecoTitle, '사회' : socTitle, '종합' : totalTitle}
    news = pd.DataFrame(data)
    
    return news

# %% [markdown]
# ## <font color = 'red'>대통령 지지율 크롤링 함수<font>
# > - 취임부터 2018년 11월까지 데이터 추출
# - 출처: 위키피디아, 한국갤럽
# - https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EC%A7%80%EC%A7%80%EC%9C%A8

# %%
import re

# 대통령 지지율 크롤링 함수
def support():
    # 위키피디아 html 가져오기
    url  = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EC%A7%80%EC%A7%80%EC%9C%A8#cite_note-%EC%B6%94%EC%84%9D-8'
    html = urlopen(url)
    soup = BeautifulSoup(html, "lxml")
    div_title = soup.find_all('tbody')[6].find_all('td')
    
    # 이중 리스트 구조를 이용해 각 주의 지지율 리스트 만들기
    weekSupportList = []
    weekSupport = []
    for n in range(len(div_title)):
        element = div_title[n].get_text().strip()
        if '미조사' in element:
            weekSupport.append('NA')
            continue
        if '월' in element:
            weekSupport = []
            weekSupportList.append(weekSupport)
        weekSupport.append(element)
    
    # 주 정보에서 년도 월 추출
    YEAR=[]
    MONTH=[]
    for element in weekSupportList:
        pattern = re.compile('(\d{4}\w)')
        year = int(pattern.search(element[0]).group()[:-1])
        pattern = re.compile('(\s\d{1,2}\w)')
        month = str(int(pattern.search(element[0]).group()[:-1])).zfill(2)
    
        YEAR.append(year)
        MONTH.append(month)
    
    # 년도와 월 합치기
    DATE=[]
    for i in range(len(MONTH)):
        date= '{year}{month}'.format(year=YEAR[i], month=MONTH[i])
        DATE.append(int(date))
        
    uniqueDate = set(DATE)
    uniqueDate = list(uniqueDate)
    
    # 지지율 추출
    PERCENT=[]
    for i in range(len(weekSupportList)):
        percent = weekSupportList[i][1]
        PERCENT.append(percent)
    
    print(len(DATE))
    print(len(PERCENT))
    
    # 초기 데이터 프레임 생성
    data = pd.DataFrame({"날짜": DATE,"지지율": PERCENT})
    data = data.set_index("날짜")
    
    # 월 지지율을 마지막 주의 지지율로 대체
    date = []
    support = []
    for i in range(len(uniqueDate)):
        if data.loc[uniqueDate[i]].iloc[-1][0] == 'NA':
            support.append(data.loc[uniqueDate[i]].iloc[-2][0])
        else:
            support.append(data.loc[uniqueDate[i]].iloc[-1][0])
        date.append(uniqueDate[i])
        
    # 최종 데이터 프레임 생성
    result = pd.DataFrame({'날짜' : date, '지지율' : support})
    result.sort_values(by = '날짜', inplace=True)
    result = result.iloc[5:]  # 1년간의 데이터만 추출
    result.set_index("날짜", inplace=True)
    
    return result

# %% [markdown]
# ## <font color = 'red'>키워드 추출하는 함수<font>
# > - 빈도수가 높은 순으로 정렬
# - 원하는 카테고리를 정해서 추출

# %%
from konlpy.tag import Okt
from collections import Counter
import re

# 상위 키워드 뽑아내는 함수
def extract_keyword(yearMonth, numOfWord, category, data,filterWord=[]):
    
    noFilterNoun = []       # 정제되지 않은 단어를 담을 공간
    filterNoun = []         # 정제된 단어를 담을 공간
    wordList = []           # 정제하고 빈도까지 체크한 단어를 담을 공간
    wordFreq = []           # 정제한 단어의 빈도 수를 담을 공간
    
    # 년도와 월 필터
    day = re.compile('{}\d+'.format(str(yearMonth)))
    
    # 지정한 년, 월에 해당하는 단어만 추출하는 과정
    okt = Okt()
    for n in range(len(data['종합'])):
        if day.search(str(data['날짜'][n])):
            noFilterNoun.extend(okt.nouns(data['{}'.format(category)][n]))
    
    # 단어 정제 과정
    for word in noFilterNoun:
        if len(word) == 1: continue
        elif word in filterWord: continue
        filterNoun.append(word)
    
    # 빈도수가 높은 단어 추출
    cnt = Counter(filterNoun)
    for word, freq in cnt.most_common(numOfWord):
        wordList.append(word)
        wordFreq.append(freq)
    
    # 데이터 프레임 형성
    colName = [(yearMonth, '단어'), (yearMonth, '빈도')]
    
    df = pd.DataFrame({'단어' :wordList, '빈도':wordFreq})
    df.rename(index=str, columns={'단어' : colName[0], '빈도' : colName[1]}, inplace=True)
    df.columns = pd.MultiIndex.from_tuples(df.columns, names=['날짜', '종류'])
    
    return df

# %% [markdown]
# ## <font color = 'red'>단어 필터<font>
# > 버전을 2가지로 형성 (많은 키워드 수집을 위한 약한 필터 / 임팩트 있는 키워드 수집을 위한 강한 필터)
# - 정치
# - 경제
# - 사회
# - 종합 (정치 경제 사회 모두를 한꺼번에 고려한 것)

# %% [markdown]
# ### 정치 필터

# %%
# 약한 필터
polMeanlessWordsWeak = []
polRepetiveWordsWeak = ['종합', '단독',  '박근', '기식', '정은', '이명', '경수', '영철', '이방', '여정','송영',
                        '주원','영남','이재','안희','희정','오늘','노회','폼페이','심재','관진', '압수', '수색',
                        '바른', '정당', '바른', '정당', '관계', '종학', '당원', '철수','처리', '현송', '대화',
                        '현진',  '실험장', '계리','주한',  '부선', '이유',  '시간', '재인', '전원', '사람', 
                        '뉴스', '개월','공중','이용','1명','지방', '20년', '계속', '출구', '세월', '특별', '9월',
                        '기무', '카드','학규', '오후', '20년', '공중', '급유기', '이용', '동연', '운전', '용석',
                        '팩트', '체크', '내년', '15년',  '연재','그린', '올해']
polFilterWordsWeak = polMeanlessWordsWeak + polRepetiveWordsWeak

# 강한 필터
polMeanlessWordsStr = []
polRepetiveWordsStr = ['종합', '단독',  '박근', '기식', '정은', '이명', '경수', '영철', '이방', '여정','송영',
                       '주원','예산','영남','이재','안희','희정','오늘','노회','폼페이','심재','대통령','국민',
                       '관진', '압수', '수색','바른', '정당','한국', '바른', '정당', '정부', '관계','종학', 
                       '정부', '당원', '철수','처리', '현송', '대화', '서울', '현진', '의원', '실험장', '계리',
                       '문대통령','주한', '대표', '부선', '이유', '장관', '시간', '재인', '문재인', '전원', 
                       '은혜', '사람', '뉴스', '개월','공중','이용', '1명','지방', '20년', '계속', '출구', 
                       '세월', '특별', '9월', '기무', '카드', '시대', '학규', '오후', '20년', '공중', '급유기',
                       '이용', '동연', '운전', '용석', '확인', '팩트', '체크', '내년', '15년', '내년', '아동',
                       '연재','그린', '올해']
polFilterWordsStr = polMeanlessWordsStr + polRepetiveWordsStr

# %% [markdown]
# ### 경제 필터

# %%
# 약한 필터
ecoMeanlessWordsWeak = []
ecoRepetiveWordsWeak = ['종합', '단독', '10', '11', '박근', '기식', '정은', '이명', '경수', '영철', '이방', '여정',
              '송영','전자','게뜨','20','군제','30','패딩','코스','비트코','가상','화폐','상화','상화폐',
              '동연','조현','대한','증권','바이오','주택자','13','부세']
ecoFilterWordsWeak = ecoMeanlessWordsWeak + ecoRepetiveWordsWeak

# 강한 필터
ecoMeanlessWordsStr = ['종합','단독','10','11','내년','한국','경제','주택자','이유','회장','개월','국민','13',
                    '종합2보']
ecoRepetiveWordsStr = ['파리','게뜨','군제','코스','패딩','가상','화폐','비트코','상화','상화폐','거래'
                       '동연','군산','공장','금호','조현','대한','양호','바이오','항공','압수','수색',
                       '부세','종합', '송영', '동연', '단독', '전자', '조현', '10', '게뜨', '대한', '11', '20', 
                       '증권', '박근', '군제', '바이오', '기식', '30', '주택자', '정은', '패딩', '13', '이명', 
                       '코스', '부세', '경수', '비트코', '영철', '가상', '이방', '화폐', '여정', '상화', 
                       '상화폐', '한국', '대통령', '파리', '삼성전자', '정부', '올해','암호', 
                       '타이어', '금호', '양호', '회장', '직스', '52', '개월', '리포트', '9월', '이후', '이유', 
                       '100', '철강관세','관세폭탄','금리인상','군산공장','논란' ]
ecoFilterWordsStr = ecoMeanlessWordsStr + ecoRepetiveWordsStr

# %% [markdown]
# ### 사회 필터

# %%
# 약한 필터
socMeanlessWordsWeak = []
socRepetiveWordsWeak = []
socFilterWordsWeak = socMeanlessWordsWeak + socRepetiveWordsWeak

# 강한 필터
socMeanlessWordsStr = []
socRepetiveWordsStr = ['르스','메르']
socFilterWordsStr = socMeanlessWordsStr + socRepetiveWordsStr

# %% [markdown]
# ### 종합 필터

# %%
# 약한 필터
totalFilterWordsWeak = polFilterWordsWeak + ecoFilterWordsWeak + socFilterWordsWeak

# 강한 필터
totalFilterWordsStr = polFilterWordsStr + ecoFilterWordsStr + socFilterWordsStr

# %% [markdown]
# ## <font color = 'red'>main 함수<font>
# > - extract_keyword 내부에서 호출 함수 이용
# - 키워드를 얻기 위한 자잘한 과정들을 내부적으로 모듈화

# %%
def main(startDay, endDay, numOfWord, category, data, filterWord=[]):
    
    # 날짜 목록 만들기
    yearMonthList = pd.period_range(start=startDay, end=endDay, freq='M')
    yearMonthList = yearMonthList.strftime('%Y%m').tolist()
    
    # 정제한 키워드 단어를 담을 데이터 프레임
    resultWords = pd.DataFrame()
    
    # 키워드 뽑아내기 (기존에 만든 extract_keyword 함수 호출)
    for yearMonth in yearMonthList:
        tmpDf = extract_keyword(yearMonth, numOfWord, category, data, filterWord)
        resultWords = pd.concat([resultWords, tmpDf], axis=1)
    
    return resultWords

# %% [markdown]
# ## <font color = 'red'>전체적인 동작<font>
# > - 기사 크롤링 함수 동작
# - 정부 지지율 크롤링 함수 동작
# - main 함수로 키워드 추출
# - 데이터 시각화

# %% [markdown]
# ### 기사 크롤링 동작

# %%
newsTop30 = crawling_news(20171101, 20181115, 30)
newsTop30
# Out:
#              날짜                                       정치  \
# 0      20171101        [종합]차은택, 징역 5년 구형에 울음…"이미 사회적 사형"
# 1      20171101      文대통령, '국민' 70번·'경제' 39번 강조…시정연설 키워드
# 2      20171101   文대통령 '국가역할론' 강조…IMF로 왜곡된 사회, 국가가 정상화(…
# 3      20171101          [종합]朴청와대, 국정원 상납금으로 4.13총선 여론조사
# 4      20171101         文대통령, 한반도 평화실현 5원칙 제시…'운전자론' 재확인
# 5      20171101         시정연설은 종합연설…文대통령 '경제·개헌' 국정구상 총망라
# 6      20171101          [단독] 조윤선·현기환에도…'월 500만원' 특활비 상납
# 7      20171101      檢, 안봉근 국정원 자금 추가수수 포착…이르면 오늘 영장(종합)
# 8      20171101           이재만·안봉근, '국정원 상납' 인정…'용돈'도 챙겼다
# 9      20171101        [단독] "국정원, 靑 모든 수석실에 월 500만원씩 줬다"
# 10     20171101        '우병우 비선보고' 추명호, 17시간 조사…영장 재청구 방침
# 11     20171101        대통령 시정연설…與 "야당 협조해야" 野 "비현실적 대책만"
# 12     20171101     文대통령 "한중관계 회복, 이제 시작…시간달라"…여야 환담(종합)
# 13     20171101      文대통령 시정연설, 박수 23번…한국당 '상복 퍼포먼스'(상보)
# 14     20171101           청와대ㆍ국정원 ‘눈먼 돈’ 거래 첫 확인… 수사 새국면
# 15     20171101          추미애 "안봉근·이재만, 단군 이래 최악의 세금 도둑질"
# 16     20171101     홍종학, 부인 상가 다운계약 의혹에 "실거래가 신고" 반박(종합)
# 17     20171101   안봉근·이재만 '국정원 상납' 시인…검찰, 뇌물 종착지 추적(종합3…
# 18     20171101           한중 정상화 발표로 사드 일단락?...불씨 여전히 잔존
# 19     20171101          검찰 '우병우 비선보고·불법사찰' 추명호 구속영장 재청구
# 20     20171101           [현장영상] 문재인 대통령, 예산안 제출 국회 시정연설
# 21     20171101          검찰, '朴 공범' 차은택에 징역 5년 구형…22일 선고
# 22     20171101         [단독] '진박 감별'에 5억…업체 대표는 정무수석실 출신
# 23     20171101      '국정원 상납' 문고리 3인방 모두 靑시절 '강남 아파트' 샀다
# 24     20171101          한중관계 '해빙', 한미동맹 변수되나?…"과제 많을 것"
# 25     20171101         홍종학 엄호 속 '역공세' 나선 민주당…내부선 '전전긍긍'
# 26     20171101         ‘흥진호 나포 사건’…국방부, 해작사·1함대에 조사단 파견
# 27     20171101   [한·중 관계 복원] 한·중 모두 파트너십 복원 절실… 사드 갈등 …
# 28     20171101      美-中 사이 한국의 ‘균형감’ 요구… 시진핑 2기의 전략적 선택
# 29     20171101        007가방에 매달 현찰 1억 배달…'국정원 뇌물죄' 성립될까
# ...         ...                                      ...
# 11370  20181115  '재판거래' 직접 챙긴 박근혜 "日 돈 보내면 프로세스 끝내라"(종합…
# 11371  20181115    국방부, 중부전선 GP 폭파 현장 공개…北도 GP 철거 작업 본격화
# 11372  20181115          北방남단, 자율주행차 '제로셔틀' 시승…이재명 지사 동행
# 11373  20181115                             철거되는 중부전선 GP
# 11374  20181115           정부 "日 강제징용 판결 비난발언 실망 금할 수 없어"
# 11375  20181115         문대통령, 아세안 정상들과 만찬…'한반도 평화 지지' 당부
# 11376  20181115          박정희 기념행사서 이철우 경북지사 “지X하고 있어” 욕설
# 11377  20181115              北 고위급 대표단 도착…김성혜 돌연 빠진 이유는?
# 11378  20181115            국회, 본회의 불발…한국·바른미래 불참에 정족수 부족
# 11379  20181115           이용주 '솜방망이 징계' 논란…'윤창호법' 수위 낮추나
# 11380  20181115     [데일리안 여론조사] '뚝뚝 떨어지는' 文대통령 지지율 51.0%
# 11381  20181115                영국의 EU 탈퇴 협정 초안…어떤 내용 담았나
# 11382  20181115           손발 안 맞는 여야, '유치원법' 표류…골든타임 놓치나
# 11383  20181115  文대통령 "한미동맹, 北 대화 이끌어"···펜스 "CVID 진전 봐야…
# 11384  20181115         이종걸 “상습적 배신자 이언주에게 비판 받으니 황당·분노”
# 11385  20181115          빅터 차 "한국 정부, 北무기소지 변호···우스꽝스럽다"
# 11386  20181115       문대통령 "한미동맹이 北 대화로 이끌어…남북·북미 함께 발전"
# 11387  20181115           국회, 본회의 불발…정국 급랭에 예산·법안 진통(종합)
# 11388  20181115        강연재 “난 흙수저 고시 출신…홍준표 안 좋아할 수 있겠나”
# 11389  20181115   이언주 "기득권 지키려는 운동권 출신 정치인들, 물러나라" 임종석 …
# 11390  20181115       설훈 "이언주 착각하고 있다, 지역구 옮긴다고 심판 못 면해"
# 11391  20181115    하태경, '반문연대' 주장한 이언주에 맞불 “극우는 보수가 아니다”
# 11392  20181115       정부 “北이 감시 눈치챌까봐 함구… 유사시 타격 준비도 끝내”
# 11393  20181115          여야 원내대표 국회 정상화 합의 불발…오늘 본회의 불투명
# 11394  20181115   [정준희의 최강시사] 윤여준 “反文이 보수 가치? 文대통령 임기 끝…
# 11395  20181115      민춘기·김산해 애국지사 유해 국내로…李총리 "조국 품에서 안식"
# 11396  20181115           펜스, 한미 이견 피하며 'CVID'로 대북원칙론 대변
# 11397  20181115           文대통령, 푸틴 이어 펜스 만난다…'北비핵화' 해법찾나
# 11398  20181115            영국의 EU 탈퇴 협정 초안…어떤 내용 담았나(종합)
# 11399  20181115            빅터 차 "北 변호하는 한국 정부 우스꽝스럽다" 비판
#
#                                                경제  \
# 0                              30대 빚내서 집 사느라 허덕인다
# 1              [종합]검찰, 롯데 신격호에 징역 10년·벌금 3000억 구형
# 2                규제의 칼날에도 집값 상승, 왜?…'버티기'에 양극화 심화
# 3                      429조 예산전쟁 개막… 공무원 증원 최대 쟁점
# 4            검찰, '채용비리' 이병삼 前금감원 부원장보 구속영장 청구(종합)
# 5                     中 시장 열린다지만…"또 당할라" 업계 투자 고심
# 6        檢, '롯데 경영비리' 신격호 징역 10년 구형…"내 회산데 뭐가 문제…
# 7       안정찾는 밥상물가…10월 소비자물가 1.8%↑, 연중 최저 '뚝'(종합2…
# 8                    검찰, '경영비리' 롯데 신격호에 징역 10년 구형
# 9                  [종합]금융공공기관 채용비리 적발시 예산삭감 등 불이익
# 10           정부·태양광업계 '세이프가드 대책회의'…WTO 제소도 검토(종합)
# 11             "보험사, 실손보험 본인부담상한 초과금액 임의로 삭감후 지급"
# 12                  빗장 풀리니 유커 행렬…'광군제' 앞두고 들뜬 유통계
# 13          [삼성전자 인사 배경·의미] 세대교체로 젊어진 삼성…미래공략 ‘트…
# 14                  코스피, 나흘 연속 사상 최고치..2556.47 마감
# 15              "묵은 쌀 220만t 남았는데"…벼 생산 줄었어도 재고 걱정
# 16                           ‘낡은 삼성’ 탈피못한 삼성전자 인사
# 17                주인 알아보고 꼬리 살랑…소니 로봇강아지 '아이보' 부활
# 18               한국, 세계은행 선정 '기업하기 좋은 나라' 4위…한단계↑
# 19            숨진 가족 보유한 건축물 정보, 내년 9월부터 유가족 쉽게 확인
# 20             KDI "근로시간 단축시 생산성↑…법정 근로시간 명확히 해야"
# 21                   검찰, '채용 비리' 합격 부모도 수사…금전 오갔나
# 22        [삼성전자 인사 배경·의미] 신임 CE 부문장 김현석…‘자발광 TV’…
# 23                  "일회용 컵 줄이겠다" 협약에도 펑펑 사용…대안 없나
# 24                    '훨훨 나는' 코스피에도 개미 투자자는 '시무룩'
# 25                가습기살균제 사태 막는다…제품안전관리원ㆍ위해평가센터 설립
# 26                    [밀착카메라] 교통량 예측 잘못…'고통의 쇼핑길'
# 27               "5년내 경기침체기 온다…차기 연준 의장, 미리 대비해야"
# 28                         김상조 “네이버 시장 지배적 지위 주시”
# 29                              금리인상 초읽기, 가계 버텨낼까
# ...                                           ...
# 11370              매매 정지에 삼바 투자자들 '발 동동'…집단 소송 준비
# 11371              주택담보대출 또 오른다…신규기준 코픽스 0.1%p 상승
# 11372           9·13대책 발표 두 달…"2억∼3억원 내려도 집 안 팔려"
# 11373              [앵커의 눈] 일자리 한파에 실업률 증가한 30~50대
# 11374         [취재파일] 풀어 쓴 '분식회계 서사시'…삼성바이오 남은 쟁점은
# 11375            경기 위축·최저임금 인상에 서울 취업자 11.6만명 줄었다
# 11376           '삼바' 분식회계…'이재용 재판·합병 무효 소송' 영향 주목
# 11377        코스피社, 3분기 누적 순익 1.92%↑...삼성전자 빼면 8%↓
# 11378           "연체 바로갚아도 신용등급에 악재…휴대폰 할부미납도 불이익"
# 11379              분양 원가 공개하면 집값 잡힐까?…시장 고민 깊어질 듯
# 11380          비트코인 가격 6천달러선 붕괴…시총도 1천억달러 밑으로(종합)
# 11381                        주유소 절반, 기름값 제대로 안내렸다
# 11382              초대형주 초유의 ‘거래 정지’…상장 폐지 여부 ‘촉각’
# 11383               CJ제일제당, 美 대형 식품업체 쉬완스 2조원에 인수
# 11384                  돼지 10마리 잡으면 족발이 50개 나오는 중국
# 11385        '환율 오르자 달러 판 기업들'…10월 외화예금 넉 달 만에 감소
# 11386           12만원 숙박 예약에 7만원 취소수수료…공정위, 티몬에 경고
# 11387         "1억7천 주고 산 벤츠 알고 보니 작년산…속았다" 소비자 분통
# 11388                대기업 진출 막는 김치산업, 정작 중국이 먹어치운다
# 11389       9·13대책 발표 두 달…"2억∼3억원 내려도 집 안 팔려"(종합)
# 11390         13년 만에 최악인 고용한파, 제조업 넘어 서비스업으로 확산 중
# 11391          바이오 업계 “예상 못한 최악의 결정… 해외 신뢰도 큰 타격”
# 11392              [마감]코스피, 4거래일만 반등성공…2090선 '바짝'
# 11393   현대그룹 등 100여명 18일 방북…"금강산 관광 재개, 관련 없어"(종…
# 11394       정성립 대우조선 사장 "내년도 흑자 가능…인력 구조조정 재검토 필…
# 11395               흡연 경고그림 내달 더 세진다…전자담배에 암세포 사진
# 11396       '3기 신도시·불안한 경제' 서울집값 하락 불가피…"딱 거기까지만"
# 11397  [Wide & deep] 카드 아니면 스마트폰… ‘현금없는 시대’ 더 가까…
# 11398          39억 ‘로또 아파트’ 당첨자는 15년 이상 무주택 7인 가족
# 11399      수능일, 증시 개폐장 1시간씩 늦춰...오전 10시~오후 4시 30분
#
#                                              사회  \
# 0                    교수→ 전공의→ 의대생… 의료계 ‘갑질 카스트’
# 1                  검찰 "이영학 변태성욕장애…성적 대상 필요해 범행"
# 2                    "악마도 살려야하나"…불붙은 '사형 부활' 여론
# 3               "유치원 입학 전쟁"…'처음학교로' 학부모 불편 덜어줄까
# 4                방문진 여권측 이사진, MBC 김장겸 사장 해임안 제출
# 5        [리포트+] 커피 쏟아서 엉망 된 버스…'음료 반입 금지'에 갑론을박
# 6                귀신 분장하고 거리 활보…'핼러윈' 어떻게 생각하세요?
# 7                  20·30대 전문·사무직 여성 보이스피싱 피해 급증
# 8               "이영학, '피해의식·변태성욕'이 만든 괴물이다"(종합)
# 9                    무면허로 렌터카 빌려 추격전...겁없는 10대들
# 10               뉴질랜드, 韓요청 받아들여 용인 일가족 살해용의자 구속
# 11                    5만원권 3장 스캐너로 위조해 성매매한 20대
# 12              공공부문 정규직 전환 17.6% 진행…1만3000명 완료
# 13           롯데월드타워 118층 전망대 있을 때 지진 난다면…첫 대피훈련
# 14                원룸 홀로 지내던 20대 여성 숨진 지 사흘 뒤 발견
# 15       '한파위험지수' 첫 산출…고흥·횡성군 등 23곳 저체온증 사망자 최…
# 16               '채용비리' 단속에 경찰 수사력 집중…연말까지 특별단속
# 17                      데이트폭력 신고해도… “폭행 당하면 오라”
# 18                   전공의 상습폭행 혐의 부산대병원 교수 영장 신청
# 19            [이슈+] 노인 10명 중 3명 ‘마음의 병’… 우울한 노년
# 20              서울 중등임용 경쟁률 여전히 '바늘구멍'… 최대 25대1
# 21       [종합]용인 일가족 살해 용의자 "의도하지 않았다" 주장…수천만원 …
# 22                오늘 오후 2시 전국 지진대피 훈련…라디오 방송 진행
# 23              [단독] 직업 없던 장남, 뉴질랜드서 '호화 저택' 임대
# 24                 몰카 영상 틀었다 '화들짝'…경찰이 남긴 경고메시지
# 25                         가락동 먹자골목 ‘퇴폐영업과의 전쟁’
# 26           부산대서 여학생 스타킹 '잉크 테러' 잇따라…20대 남성 추적
# 27           부산대서 여학생 스타킹 '잉크 테러' 잇따라…20대 남성 추적
# 28                    은영씨가 삼성 보상 거부하고 산재신청 한 이유
# 29             소방헬기 담수용량 속이고 전북도에 대여…임대업자 2명 입건
# ...                                         ...
# 11370  '이수역 폭행' 경찰, 남성 3명·여성 2명 '쌍방폭행' 모두 입건(종…
# 11371      'PC방 살인' 김성수 동생 공범 논란 가열…흉기 꺼낸 시점 관건
# 11372              수험생 "국어인지 과학인지"…우주론 다룬 문제 등장
# 11373     법무부 "PC방 살인 김성수 심신미약 아니다"…정신감정 결론(종합)
# 11374               수능 국어영역, 김춘수 시 지문·보기에서 오·탈자
# 11375        남혐·여혐 대결로 번진 '이수역 폭행'…국민청원 30만명 넘어
# 11376          자녀와 같은 고교 다니는 교사 900명…내신비리 근절대책은
# 11377      경찰 "'이수역 폭행' 여성 일행이 먼저 소란"…목격자 진술 확보
# 11378       [수능] 필적확인문구 '그대만큼 사랑스러운 사람을 본일이 없다"
# 11379         쌍둥이 측 "9월 모의고사, 언니는 수학 빼고 모두 1등급"
# 11380           '이수역 폭행' 추가 영상 공개...논란 커져 수사 지연
# 11381          '이수역 폭행' 피의자들 "논란 커지며 두려움" 조사 연기
# 11382                          두팔 벌려 딸 안아주는 학부모
# 11383       “학생이 범인” 단정짓고… 부모 모르게 43명 지문 채취한 경찰
# 11384    1등석 비행기표 사서 출국장까지 졸졸… '오빠' 떠나면 표 취소하는…
# 11385         국어가 불지른 '불수능'…"수험생들 1교시 끝나자마자 멘붕"
# 11386             폭행당한 중학생 추락사...가해자들 "자살로 만들자"
# 11387        "모든 서울시민을 김정은 환영단으로…" 활동 시작한 백두칭송위
# 11388    [2019수능]수학 가·나형 모두 어려웠다…출제범위·난이도 작년과 …
# 11389      ‘논산 여교사’ 사건의 남학생 “관계 찍자고도 했는데…” (영상)
# 11390           석촌호수서 발견된 '실종 대학생', 외상 없어…익사 확인
# 11391          [단독] 잇따라 2명 숨진 병원…무면허 의사·영업사원 수술
# 11392            광주 수험생, 2교시 앞두고 복통으로 병원행…수능 포기
# 11393     [수능]올해도 불수능…수학가 빼곤 1등급컷 80점대 예상(종합2보)
# 11394           마치 지하철 탄듯…조용하고 흔들림 없는 서울 첫 전기버스
# 11395          [수능]올해도 불수능…수학가 빼곤 1등급 컷 80점대 예상
# 11396            진주서 발견 1㎝ 랩터 공룡발자국 화석…세계 최소 인정
# 11397        이수역 폭행사건 발생… "남자 넷이 여자 둘 폭행, 도와달라"
# 11398                       [수능정답]국어 영역 정답표 홀수형
# 11399    [끝까지판다③] "고양이한테 생선 맡긴 격"…징계 비웃는 '비리 사…
#
#                                                       종합
# 0      [종합]차은택, 징역 5년 구형에 울음…"이미 사회적 사형" 30대 빚내서 집 사느...
# 1      文대통령, '국민' 70번·'경제' 39번 강조…시정연설 키워드 [종합]검찰, 롯데...
# 2      文대통령 '국가역할론' 강조…IMF로 왜곡된 사회, 국가가 정상화(… 규제의 칼날에...
# 3      [종합]朴청와대, 국정원 상납금으로 4.13총선 여론조사 429조 예산전쟁 개막… ...
# 4      文대통령, 한반도 평화실현 5원칙 제시…'운전자론' 재확인 검찰, '채용비리' 이병...
# 5      시정연설은 종합연설…文대통령 '경제·개헌' 국정구상 총망라 中 시장 열린다지만…"또...
# 6      [단독] 조윤선·현기환에도…'월 500만원' 특활비 상납 檢, '롯데 경영비리' 신...
# 7      檢, 안봉근 국정원 자금 추가수수 포착…이르면 오늘 영장(종합) 안정찾는 밥상물가…...
# 8      이재만·안봉근, '국정원 상납' 인정…'용돈'도 챙겼다 검찰, '경영비리' 롯데 신...
# 9      [단독] "국정원, 靑 모든 수석실에 월 500만원씩 줬다" [종합]금융공공기관 채...
# 10     '우병우 비선보고' 추명호, 17시간 조사…영장 재청구 방침 정부·태양광업계 '세이...
# 11     대통령 시정연설…與 "야당 협조해야" 野 "비현실적 대책만" "보험사, 실손보험 본...
# 12     文대통령 "한중관계 회복, 이제 시작…시간달라"…여야 환담(종합) 빗장 풀리니 유커...
# 13     文대통령 시정연설, 박수 23번…한국당 '상복 퍼포먼스'(상보) [삼성전자 인사 배...
# 14     청와대ㆍ국정원 ‘눈먼 돈’ 거래 첫 확인… 수사 새국면 코스피, 나흘 연속 사상 최...
# 15     추미애 "안봉근·이재만, 단군 이래 최악의 세금 도둑질" "묵은 쌀 220만t 남았...
# 16     홍종학, 부인 상가 다운계약 의혹에 "실거래가 신고" 반박(종합) ‘낡은 삼성’ 탈...
# 17     안봉근·이재만 '국정원 상납' 시인…검찰, 뇌물 종착지 추적(종합3… 주인 알아보고...
# 18     한중 정상화 발표로 사드 일단락?...불씨 여전히 잔존 한국, 세계은행 선정 '기업...
# 19     검찰 '우병우 비선보고·불법사찰' 추명호 구속영장 재청구 숨진 가족 보유한 건축물 ...
# 20     [현장영상] 문재인 대통령, 예산안 제출 국회 시정연설 KDI "근로시간 단축시 생...
# 21     검찰, '朴 공범' 차은택에 징역 5년 구형…22일 선고 검찰, '채용 비리' 합격...
# 22     [단독] '진박 감별'에 5억…업체 대표는 정무수석실 출신 [삼성전자 인사 배경·의...
# 23     '국정원 상납' 문고리 3인방 모두 靑시절 '강남 아파트' 샀다 "일회용 컵 줄이겠...
# 24     한중관계 '해빙', 한미동맹 변수되나?…"과제 많을 것" '훨훨 나는' 코스피에도 ...
# 25     홍종학 엄호 속 '역공세' 나선 민주당…내부선 '전전긍긍' 가습기살균제 사태 막는다...
# 26     ‘흥진호 나포 사건’…국방부, 해작사·1함대에 조사단 파견 [밀착카메라] 교통량 예...
# 27     [한·중 관계 복원] 한·중 모두 파트너십 복원 절실… 사드 갈등 … "5년내 경기...
# 28     美-中 사이 한국의 ‘균형감’ 요구… 시진핑 2기의 전략적 선택 김상조 “네이버 시...
# 29     007가방에 매달 현찰 1억 배달…'국정원 뇌물죄' 성립될까 금리인상 초읽기, 가계...
# ...                                                  ...
# 11370  '재판거래' 직접 챙긴 박근혜 "日 돈 보내면 프로세스 끝내라"(종합… 매매 정지에...
# 11371  국방부, 중부전선 GP 폭파 현장 공개…北도 GP 철거 작업 본격화 주택담보대출 또...
# 11372  北방남단, 자율주행차 '제로셔틀' 시승…이재명 지사 동행 9·13대책 발표 두 달…...
# 11373  철거되는 중부전선 GP [앵커의 눈] 일자리 한파에 실업률 증가한 30~50대 법무...
# 11374  정부 "日 강제징용 판결 비난발언 실망 금할 수 없어" [취재파일] 풀어 쓴 '분식...
# 11375  문대통령, 아세안 정상들과 만찬…'한반도 평화 지지' 당부 경기 위축·최저임금 인상...
# 11376  박정희 기념행사서 이철우 경북지사 “지X하고 있어” 욕설 '삼바' 분식회계…'이재용...
# 11377  北 고위급 대표단 도착…김성혜 돌연 빠진 이유는? 코스피社, 3분기 누적 순익 1....
# 11378  국회, 본회의 불발…한국·바른미래 불참에 정족수 부족 "연체 바로갚아도 신용등급에 ...
# 11379  이용주 '솜방망이 징계' 논란…'윤창호법' 수위 낮추나 분양 원가 공개하면 집값 잡...
# 11380  [데일리안 여론조사] '뚝뚝 떨어지는' 文대통령 지지율 51.0% 비트코인 가격 6...
# 11381  영국의 EU 탈퇴 협정 초안…어떤 내용 담았나 주유소 절반, 기름값 제대로 안내렸다...
# 11382  손발 안 맞는 여야, '유치원법' 표류…골든타임 놓치나 초대형주 초유의 ‘거래 정지...
# 11383  文대통령 "한미동맹, 北 대화 이끌어"···펜스 "CVID 진전 봐야… CJ제일제당...
# 11384  이종걸 “상습적 배신자 이언주에게 비판 받으니 황당·분노” 돼지 10마리 잡으면 족...
# 11385  빅터 차 "한국 정부, 北무기소지 변호···우스꽝스럽다" '환율 오르자 달러 판 기...
# 11386  문대통령 "한미동맹이 北 대화로 이끌어…남북·북미 함께 발전" 12만원 숙박 예약에...
# 11387  국회, 본회의 불발…정국 급랭에 예산·법안 진통(종합) "1억7천 주고 산 벤츠 알...
# 11388  강연재 “난 흙수저 고시 출신…홍준표 안 좋아할 수 있겠나” 대기업 진출 막는 김치...
# 11389  이언주 "기득권 지키려는 운동권 출신 정치인들, 물러나라" 임종석 … 9·13대책 ...
# 11390  설훈 "이언주 착각하고 있다, 지역구 옮긴다고 심판 못 면해" 13년 만에 최악인 ...
# 11391  하태경, '반문연대' 주장한 이언주에 맞불 “극우는 보수가 아니다” 바이오 업계 “...
# 11392  정부 “北이 감시 눈치챌까봐 함구… 유사시 타격 준비도 끝내” [마감]코스피, 4거...
# 11393  여야 원내대표 국회 정상화 합의 불발…오늘 본회의 불투명 현대그룹 등 100여명 1...
# 11394  [정준희의 최강시사] 윤여준 “反文이 보수 가치? 文대통령 임기 끝… 정성립 대우조...
# 11395  민춘기·김산해 애국지사 유해 국내로…李총리 "조국 품에서 안식" 흡연 경고그림 내달...
# 11396  펜스, 한미 이견 피하며 'CVID'로 대북원칙론 대변 '3기 신도시·불안한 경제'...
# 11397  文대통령, 푸틴 이어 펜스 만난다…'北비핵화' 해법찾나 [Wide & deep] 카...
# 11398  영국의 EU 탈퇴 협정 초안…어떤 내용 담았나(종합) 39억 ‘로또 아파트’ 당첨자...
# 11399  빅터 차 "北 변호하는 한국 정부 우스꽝스럽다" 비판 수능일, 증시 개폐장 1시간씩...
#
# [11400 rows x 5 columns]

# %%
# 기사 TOP 30 파일 저장

newsTop30.to_csv('data/naver_news_top30.csv', sep=',', encoding='UTF-8')
newsTop30.to_excel('data/naver_news_top30.xlsx')

# %%
# 저장한 뉴스 헤드라인 파일 읽어오기

newsTop5 = pd.read_csv('data/naver_news_top5.csv', encoding='UTF-8')
newsTop5.drop('Unnamed: 0', axis=1, inplace=True)
newsTop5.head()
# Out:
#          날짜                                      정치  \
# 0  20171101       [종합]차은택, 징역 5년 구형에 울음…"이미 사회적 사형"
# 1  20171101     文대통령, '국민' 70번·'경제' 39번 강조…시정연설 키워드
# 2  20171101  文대통령 '국가역할론' 강조…IMF로 왜곡된 사회, 국가가 정상화(…
# 3  20171101         [종합]朴청와대, 국정원 상납금으로 4.13총선 여론조사
# 4  20171101        文대통령, 한반도 평화실현 5원칙 제시…'운전자론' 재확인
#
#                                      경제                               사회  \
# 0                    30대 빚내서 집 사느라 허덕인다       교수→ 전공의→ 의대생… 의료계 ‘갑질 카스트’
# 1    [종합]검찰, 롯데 신격호에 징역 10년·벌금 3000억 구형     검찰 "이영학 변태성욕장애…성적 대상 필요해 범행"
# 2      규제의 칼날에도 집값 상승, 왜?…'버티기'에 양극화 심화       "악마도 살려야하나"…불붙은 '사형 부활' 여론
# 3            429조 예산전쟁 개막… 공무원 증원 최대 쟁점  "유치원 입학 전쟁"…'처음학교로' 학부모 불편 덜어줄까
# 4  검찰, '채용비리' 이병삼 前금감원 부원장보 구속영장 청구(종합)   방문진 여권측 이사진, MBC 김장겸 사장 해임안 제출
#
#                                                   종합
# 0  [종합]차은택, 징역 5년 구형에 울음…"이미 사회적 사형" 30대 빚내서 집 사느...
# 1  文대통령, '국민' 70번·'경제' 39번 강조…시정연설 키워드 [종합]검찰, 롯데...
# 2  文대통령 '국가역할론' 강조…IMF로 왜곡된 사회, 국가가 정상화(… 규제의 칼날에...
# 3  [종합]朴청와대, 국정원 상납금으로 4.13총선 여론조사 429조 예산전쟁 개막… ...
# 4  文대통령, 한반도 평화실현 5원칙 제시…'운전자론' 재확인 검찰, '채용비리' 이병...

# %% [markdown]
# ### 정부 지지율 크롤링 동작

# %%
governmentSupport = support()
governmentSupport.head()
# Out:
# 79
# 79
#           지지율
# 날짜
# 201710  73.0%
# 201711  75.0%
# 201712  68.5%
# 201801  64.0%
# 201802  64.0%

# %%
# 정부 지지율 파일 저장

governmentSupport.to_csv('data/governmentSupport.csv')
governmentSupport.to_excel('data/governmentSupport.xlsx')

# %%
# 정부 지지율 파일 읽어오기

governmentSupport = pd.read_csv('data/governmentSupport.csv', encoding='UTF-8')
governmentSupport.head()
# Out:
#        날짜    지지율
# 0  201710  73.0%
# 1  201711  75.0%
# 2  201712  68.5%
# 3  201801  64.0%
# 4  201802  64.0%

# %% [markdown]
# ### main 함수 동작 > 키워드 추출

# %%
totalWords5 = main(20171101, 20181101, 5, '종합', newsTop5, totalFilterWordsStr)
totalWords5
# Out:
# 날짜 201711     201712     201801     201802     201803     ... 201807      \
# 종류     단어  빈도     단어  빈도     단어  빈도     단어  빈도     단어  빈도 ...     단어  빈도
# 0      귀순  24   비트코인  28   최저임금  19     검사  14     미투  23 ...     폭염  25
# 1      검찰  14     화재  15     거래  14    박근혜  14    안희정  19 ...     사망  19
# 2      북한  14     제천  14   비트코인  14    성추행  13    성추행  18 ...   최저임금  18
# 3      포항  13     사망  12     수사  14     검찰  12     의혹  16 ...     전쟁  15
# 4      지진  13     거래  11    현송월  14     지원  12    정봉주  16 ...    기무사  14
#
# 날짜 201808     201809     201810     201811
# 종류     단어  빈도     단어  빈도     단어  빈도     단어 빈도
# 0      태풍  22     평양  30    아파트  19     폭행  9
# 1     김경수  20     주택  26     주택  12    쌍둥이  8
# 2      폭염  18    김정은  26    이재명  12    양진호  7
# 3      솔릭  18    부동산  16     살인  12   숙명여고  7
# 4      집값  16     대책  16    유치원  11     교체  6
#
# [5 rows x 26 columns]

# %%
# 키워드 파일 저장

totalWords5.to_csv('data/keyword_total_top5_strong_ver1.csv', sep=',', encoding='UTF-8')
totalWords5.to_excel('data/keyword_total_top5_strong_ver1.xlsx', encoding='UTF-8')

# %%
# 키워드 파일 읽어오기

totalWords5 = pd.read_csv('data/keyword_total_top30.csv', header=[0,1], encoding='UTF-8')
# totalWords30.drop('Unnamed: 0', axis=1, inplace=True)
totalWords5.head()
# Out:
#   날짜 201711      201712      201801      201802      201803 ... 201807       \
#   종류     단어   빈도     단어   빈도     단어   빈도     단어   빈도     단어 ...     단어   빈도
# 0  0    대통령  110    대통령  120     정부  130    대통령  136    대통령 ...    대통령  128
# 1  1     포항   99     정부  106    대통령  124     정부   93     미투 ...     폭염   97
# 2  2     검찰   92     사망   72   가상화폐   91     추행   73     관세 ...    기무사   84
# 3  3     지진   92     조사   61     검찰   82    올림픽   69    안희정 ...     문건   76
# 4  4     수사   73     검찰   60     통합   74     수사   67    트럼프 ...     계엄   62
#
#   201808      201809      201810      201811
#       단어   빈도     단어   빈도     단어   빈도     단어  빈도
# 0    대통령  108    대통령  190    대통령  156    대통령  65
# 1    김경수  102     회담  116    유치원   90     폭행  39
# 2     서울   87     서울  115     서울   81     경찰  38
# 3     폭염   86     정상  109    아파트   63     서울  38
# 4     정부   83     집값  108    코스피   60     진호  34
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
